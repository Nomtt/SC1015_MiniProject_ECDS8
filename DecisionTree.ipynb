# %% [markdown]
# ### Disclaimer:
# Please note that due to shuffling in an earlier stage, the accuracy rates may vary slightly from those presented in our initial presentation and our main complete codebase. We have taken steps to minimize such discrepancies in the future. We apologize for any inconsistencies.

# %% [markdown]
# # Part 4: Deciion Tree Classification

# %% [markdown]
# We first used __Decision Tree Classifier__ on each of the four train/test data sets we have initialized above. In the following way, we will determine accuracies and demonstrate the confusion matrix and decision tree upon concluding this section.

# %% [markdown]
# ### Importing libraries and datasets

# %%
# For data processing
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
sb.set(style='whitegrid')

X_train = pd.read_csv('2X1_train.csv')
X_test = pd.read_csv('2X1_test.csv')
X2_train = pd.read_csv('2X2_train.csv')
X2_test = pd.read_csv('2X2_test.csv')
X3_train = pd.read_csv('2X3_train.csv')
X3_test = pd.read_csv('2X3_test.csv')
X4_train = pd.read_csv('2X4_train.csv')
X4_test = pd.read_csv('2X4_test.csv')

# %%
# Decision Tree using Train Data
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

dectree = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object

# %%
dectree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %% [markdown]
# ### 1.1. Decision Tree Classifier for __X_train__ dataset.

# %%
# Predict Response corresponding to Predictors
y_train_pred1 = dectree.predict(X_train)
y_test_pred1 = dectree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred1),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred1), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

from sklearn.metrics import confusion_matrix

# Get confusion matrix values for train and test
cm_train = confusion_matrix(y_train, y_train_pred1)
cm_test = confusion_matrix(y_test, y_test_pred1)

def print_rates(cm, dataset_name=""):
    TN, FP, FN, TP = cm.ravel()

    FNR = FN / (FN + TP) if (FN + TP) != 0 else 0
    FPR = FP / (FP + TN) if (FP + TN) != 0 else 0
    TPR = TP / (TP + FN) if (TP + FN) != 0 else 0
    TNR = TN / (TN + FP) if (TN + FP) != 0 else 0

    print(f"Rates for {dataset_name} Dataset:")
    print(f"False Negative Rate (FNR): {FNR:.4f}")
    print(f"False Positive Rate (FPR): {FPR:.4f}")
    print(f"True Positive Rate (TPR / Recall): {TPR:.4f}")
    print(f"True Negative Rate (TNR / Specificity): {TNR:.4f}")
    print()

# Print rates for both train and test
print_rates(cm_train, "Train")
print_rates(cm_test, "Test")
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7874564459930313
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.71875
#
# Rates for Train Dataset:
# False Negative Rate (FNR): 0.6867
# False Positive Rate (FPR): 0.0196
# True Positive Rate (TPR / Recall): 0.3133
# True Negative Rate (TNR / Specificity): 0.9804
#
# Rates for Test Dataset:
# False Negative Rate (FNR): 0.7200
# False Positive Rate (FPR): 0.1268
# True Positive Rate (TPR / Recall): 0.2800
# True Negative Rate (TNR / Specificity): 0.8732

# %%
from sklearn.tree import plot_tree

f = plt.figure(figsize=(30,15))
plot_tree(dectree, filled=True, rounded=True, 
          feature_names=X_train.columns, 
          class_names=["Age", "Gender", "Smoking History"])
# Out:
# [Text(0.6041666666666666, 0.9, 'Gender <= 0.5\ngini = 0.411\nsamples = 287\nvalue = [204, 83]\nclass = Age'),
#  Text(0.3333333333333333, 0.7, 'Age <= 55.5\ngini = 0.337\nsamples = 233\nvalue = [183, 50]\nclass = Age'),
#  Text(0.16666666666666666, 0.5, 'Age <= 21.5\ngini = 0.272\nsamples = 197\nvalue = [165.0, 32.0]\nclass = Age'),
#  Text(0.08333333333333333, 0.3, 'Age <= 18.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]\nclass = Age'),
#  Text(0.041666666666666664, 0.1, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Age'),
#  Text(0.125, 0.1, 'gini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Age'),
#  Text(0.25, 0.3, 'Age <= 30.5\ngini = 0.253\nsamples = 182\nvalue = [155, 27]\nclass = Age'),
#  Text(0.20833333333333334, 0.1, 'gini = 0.175\nsamples = 62\nvalue = [56, 6]\nclass = Age'),
#  Text(0.2916666666666667, 0.1, 'gini = 0.289\nsamples = 120\nvalue = [99, 21]\nclass = Age'),
#  Text(0.5, 0.5, 'Age <= 72.5\ngini = 0.5\nsamples = 36\nvalue = [18, 18]\nclass = Age'),
#  Text(0.4166666666666667, 0.3, 'Age <= 68.5\ngini = 0.495\nsamples = 31\nvalue = [17, 14]\nclass = Age'),
#  Text(0.375, 0.1, 'gini = 0.5\nsamples = 26\nvalue = [13, 13]\nclass = Age'),
#  Text(0.4583333333333333, 0.1, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Age'),
#  Text(0.5833333333333334, 0.3, 'Age <= 80.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Gender'),
#  Text(0.5416666666666666, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Gender'),
#  Text(0.625, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Age'),
#  Text(0.875, 0.7, 'Age <= 61.5\ngini = 0.475\nsamples = 54\nvalue = [21, 33]\nclass = Gender'),
#  Text(0.8333333333333334, 0.5, 'Age <= 25.5\ngini = 0.5\nsamples = 43\nvalue = [21, 22]\nclass = Gender'),
#  Text(0.75, 0.3, 'Age <= 20.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Age'),
#  Text(0.7083333333333334, 0.1, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Age'),
#  Text(0.7916666666666666, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Age'),
#  Text(0.9166666666666666, 0.3, 'Age <= 40.5\ngini = 0.494\nsamples = 38\nvalue = [17.0, 21.0]\nclass = Gender'),
#  Text(0.875, 0.1, 'gini = 0.391\nsamples = 15\nvalue = [4, 11]\nclass = Gender'),
#  Text(0.9583333333333334, 0.1, 'gini = 0.491\nsamples = 23\nvalue = [13.0, 10.0]\nclass = Age'),
#  Text(0.9166666666666666, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Gender')]

# %% [markdown]
# ### 1.2. Decision Tree Classifier for __X2_train__ dataset.

# %%
dectree2 = DecisionTreeClassifier(max_depth = 4)
dectree2.fit(X2_train, y2_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
from sklearn.tree import plot_tree

f = plt.figure(figsize=(40,12))
plot_tree(dectree2, filled=True, rounded=True, 
          feature_names=X2_train.columns, 
          class_names=["Age", "Gender", "Currently Smoking", "Smoking History", "Adenopathy"])
# Out:
# [Text(0.5833333333333334, 0.9, 'Adenopathy <= 0.5\ngini = 0.402\nsamples = 287\nvalue = [207, 80]\nclass = Age'),
#  Text(0.35714285714285715, 0.7, 'Age <= 55.5\ngini = 0.182\nsamples = 208\nvalue = [187, 21]\nclass = Age'),
#  Text(0.19047619047619047, 0.5, 'Age <= 18.0\ngini = 0.088\nsamples = 173\nvalue = [165, 8]\nclass = Age'),
#  Text(0.09523809523809523, 0.3, 'Smoking History <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Age'),
#  Text(0.047619047619047616, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Gender'),
#  Text(0.14285714285714285, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Age'),
#  Text(0.2857142857142857, 0.3, 'Age <= 37.5\ngini = 0.079\nsamples = 171\nvalue = [164, 7]\nclass = Age'),
#  Text(0.23809523809523808, 0.1, 'gini = 0.108\nsamples = 105\nvalue = [99, 6]\nclass = Age'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.03\nsamples = 66\nvalue = [65, 1]\nclass = Age'),
#  Text(0.5238095238095238, 0.5, 'Currently Smoking <= 0.5\ngini = 0.467\nsamples = 35\nvalue = [22, 13]\nclass = Age'),
#  Text(0.47619047619047616, 0.3, 'Gender <= 0.5\ngini = 0.412\nsamples = 31\nvalue = [22, 9]\nclass = Age'),
#  Text(0.42857142857142855, 0.1, 'gini = 0.366\nsamples = 29\nvalue = [22, 7]\nclass = Age'),
#  Text(0.5238095238095238, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Gender'),
#  Text(0.5714285714285714, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Gender'),
#  Text(0.8095238095238095, 0.7, 'Adenopathy <= 1.5\ngini = 0.378\nsamples = 79\nvalue = [20, 59]\nclass = Gender'),
#  Text(0.7142857142857143, 0.5, 'Age <= 52.0\ngini = 0.493\nsamples = 34\nvalue = [15, 19]\nclass = Gender'),
#  Text(0.6666666666666666, 0.3, 'Gender <= 0.5\ngini = 0.497\nsamples = 28\nvalue = [15, 13]\nclass = Age'),
#  Text(0.6190476190476191, 0.1, 'gini = 0.463\nsamples = 22\nvalue = [14, 8]\nclass = Age'),
#  Text(0.7142857142857143, 0.1, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Gender'),
#  Text(0.7619047619047619, 0.3, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Gender'),
#  Text(0.9047619047619048, 0.5, 'Gender <= 0.5\ngini = 0.198\nsamples = 45\nvalue = [5, 40]\nclass = Gender'),
#  Text(0.8571428571428571, 0.3, 'Age <= 54.0\ngini = 0.302\nsamples = 27\nvalue = [5, 22]\nclass = Gender'),
#  Text(0.8095238095238095, 0.1, 'gini = 0.363\nsamples = 21\nvalue = [5, 16]\nclass = Gender'),
#  Text(0.9047619047619048, 0.1, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Gender'),
#  Text(0.9523809523809523, 0.3, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]\nclass = Gender')]

# %%
# Predict Response corresponding to Predictors
y_train_pred2 = dectree2.predict(X2_train)
y_test_pred2 = dectree2.predict(X2_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree2.score(X2_train, y2_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree2.score(X2_test, y2_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y2_train, y_train_pred2),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y2_test, y_test_pred2), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

from sklearn.metrics import confusion_matrix

# Get confusion matrix values for train and test
cm_train2 = confusion_matrix(y2_train, y_train_pred2)
cm_test2 = confusion_matrix(y2_test, y_test_pred2)

def print_rates(cm, dataset_name=""):
    TN, FP, FN, TP = cm.ravel()

    FNR = FN / (FN + TP) if (FN + TP) != 0 else 0
    FPR = FP / (FP + TN) if (FP + TN) != 0 else 0
    TPR = TP / (TP + FN) if (TP + FN) != 0 else 0
    TNR = TN / (TN + FP) if (TN + FP) != 0 else 0

    print(f"Rates for {dataset_name} Dataset:")
    print(f"False Negative Rate (FNR): {FNR:.4f}")
    print(f"False Positive Rate (FPR): {FPR:.4f}")
    print(f"True Positive Rate (TPR / Recall): {TPR:.4f}")
    print(f"True Negative Rate (TNR / Specificity): {TNR:.4f}")
    print()

# Print rates for both train and test
print_rates(cm_train2, "Train")
print_rates(cm_test2, "Test")
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9024390243902439
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.7708333333333334
#
# Rates for Train Dataset:
# False Negative Rate (FNR): 0.2750
# False Positive Rate (FPR): 0.0290
# True Positive Rate (TPR / Recall): 0.7250
# True Negative Rate (TNR / Specificity): 0.9710
#
# Rates for Test Dataset:
# False Negative Rate (FNR): 0.4286
# False Positive Rate (FPR): 0.1471
# True Positive Rate (TPR / Recall): 0.5714
# True Negative Rate (TNR / Specificity): 0.8529

# %% [markdown]
# ### 1.3. Decision Tree Classifier for __X3_train__ dataset.

# %%
dectree3 = DecisionTreeClassifier(max_depth = 4)
dectree3.fit(X3_train, y3_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
from sklearn.tree import plot_tree

f = plt.figure(figsize=(40,12))
plot_tree(dectree3, filled=True, rounded=True, 
          feature_names=X3_train.columns, 
          class_names=["Age", "Gender", "Currently Smoking", "Smoking History", "Adenopathy", "Risk", "Treatment Response"])
# Out:
# [Text(0.4, 0.9, 'Treatment Response <= 2.5\ngini = 0.405\nsamples = 287\nvalue = [206, 81]\nclass = Age'),
#  Text(0.2, 0.7, 'Risk <= 0.5\ngini = 0.113\nsamples = 217\nvalue = [204, 13]\nclass = Age'),
#  Text(0.1, 0.5, 'gini = 0.0\nsamples = 177\nvalue = [177, 0]\nclass = Age'),
#  Text(0.3, 0.5, 'Treatment Response <= 1.5\ngini = 0.439\nsamples = 40\nvalue = [27, 13]\nclass = Age'),
#  Text(0.2, 0.3, 'Age <= 57.0\ngini = 0.298\nsamples = 33\nvalue = [27, 6]\nclass = Age'),
#  Text(0.1, 0.1, 'gini = 0.185\nsamples = 29\nvalue = [26, 3]\nclass = Age'),
#  Text(0.3, 0.1, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Gender'),
#  Text(0.4, 0.3, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Gender'),
#  Text(0.6, 0.7, 'Adenopathy <= 2.5\ngini = 0.056\nsamples = 70\nvalue = [2, 68]\nclass = Gender'),
#  Text(0.5, 0.5, 'gini = 0.0\nsamples = 41\nvalue = [0, 41]\nclass = Gender'),
#  Text(0.7, 0.5, 'Risk <= 0.5\ngini = 0.128\nsamples = 29\nvalue = [2, 27]\nclass = Gender'),
#  Text(0.6, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Age'),
#  Text(0.8, 0.3, 'Adenopathy <= 3.5\ngini = 0.069\nsamples = 28\nvalue = [1, 27]\nclass = Gender'),
#  Text(0.7, 0.1, 'gini = 0.198\nsamples = 9\nvalue = [1, 8]\nclass = Gender'),
#  Text(0.9, 0.1, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]\nclass = Gender')]

# %%
# Predict Response corresponding to Predictors
y_train_pred3 = dectree3.predict(X3_train)
y_test_pred3 = dectree3.predict(X3_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree3.score(X3_train, y3_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree3.score(X3_test, y3_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y3_train, y_train_pred3),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y3_test, y_test_pred3), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

# Get confusion matrix values for train and test
cm_train3 = confusion_matrix(y3_train, y_train_pred3)
cm_test3 = confusion_matrix(y3_test, y_test_pred3)

def print_rates(cm, dataset_name=""):
    TN, FP, FN, TP = cm.ravel()

    FNR = FN / (FN + TP) if (FN + TP) != 0 else 0
    FPR = FP / (FP + TN) if (FP + TN) != 0 else 0
    TPR = TP / (TP + FN) if (TP + FN) != 0 else 0
    TNR = TN / (TN + FP) if (TN + FP) != 0 else 0

    print(f"Rates for {dataset_name} Dataset:")
    print(f"False Negative Rate (FNR): {FNR:.4f}")
    print(f"False Positive Rate (FPR): {FPR:.4f}")
    print(f"True Positive Rate (TPR / Recall): {TPR:.4f}")
    print(f"True Negative Rate (TNR / Specificity): {TNR:.4f}")
    print()

# Print rates for both train and test
print_rates(cm_train3, "Train")
print_rates(cm_test3, "Test")
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9825783972125436
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9375
#
# Rates for Train Dataset:
# False Negative Rate (FNR): 0.0370
# False Positive Rate (FPR): 0.0097
# True Positive Rate (TPR / Recall): 0.9630
# True Negative Rate (TNR / Specificity): 0.9903
#
# Rates for Test Dataset:
# False Negative Rate (FNR): 0.1111
# False Positive Rate (FPR): 0.0435
# True Positive Rate (TPR / Recall): 0.8889
# True Negative Rate (TNR / Specificity): 0.9565

# %% [markdown]
# ### 1.4. Decision Tree Classifier for __X4_train__ dataset.

# %%
dectree4 = DecisionTreeClassifier(max_depth = 4)
dectree4.fit(X4_train, y4_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
from sklearn.tree import plot_tree

f = plt.figure(figsize=(40,12))
plot_tree(dectree4, filled=True, rounded=True, 
          feature_names=X4_train.columns, 
          class_names=["Age", "Gender", "Currently Smoking", "Smoking History", "Radiotherapy History", "Thyroid Function", "Physical Examination", "Adenopathy", 
                    "Types of Thyroid Cancer (Pathology)", "Focality", "Risk", "Tumor", 
                    "Lymph Nodes", "Cancer Metastasis", "Stage", "Treatment Response"])
# Out:
# [Text(0.631578947368421, 0.9, 'Treatment Response <= 2.5\ngini = 0.405\nsamples = 287\nvalue = [206, 81]\nclass = Age'),
#  Text(0.42105263157894735, 0.7, 'Treatment Response <= 1.5\ngini = 0.128\nsamples = 219\nvalue = [204, 15]\nclass = Age'),
#  Text(0.21052631578947367, 0.5, 'Risk <= 0.5\ngini = 0.058\nsamples = 199\nvalue = [193, 6]\nclass = Age'),
#  Text(0.10526315789473684, 0.3, 'Treatment Response <= 0.5\ngini = 0.012\nsamples = 171\nvalue = [170, 1]\nclass = Age'),
#  Text(0.05263157894736842, 0.1, 'gini = 0.0\nsamples = 140\nvalue = [140, 0]\nclass = Age'),
#  Text(0.15789473684210525, 0.1, 'gini = 0.062\nsamples = 31\nvalue = [30, 1]\nclass = Age'),
#  Text(0.3157894736842105, 0.3, 'Age <= 64.5\ngini = 0.293\nsamples = 28\nvalue = [23, 5]\nclass = Age'),
#  Text(0.2631578947368421, 0.1, 'gini = 0.252\nsamples = 27\nvalue = [23, 4]\nclass = Age'),
#  Text(0.3684210526315789, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Gender'),
#  Text(0.631578947368421, 0.5, 'Risk <= 0.5\ngini = 0.495\nsamples = 20\nvalue = [11, 9]\nclass = Age'),
#  Text(0.5263157894736842, 0.3, 'Thyroid Function <= 1.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = Age'),
#  Text(0.47368421052631576, 0.1, 'gini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Age'),
#  Text(0.5789473684210527, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Gender'),
#  Text(0.7368421052631579, 0.3, 'Age <= 32.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Gender'),
#  Text(0.6842105263157895, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Age'),
#  Text(0.7894736842105263, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Gender'),
#  Text(0.8421052631578947, 0.7, 'Types of Thyroid Cancer (Pathology) <= 2.5\ngini = 0.057\nsamples = 68\nvalue = [2, 66]\nclass = Gender'),
#  Text(0.7894736842105263, 0.5, 'gini = 0.0\nsamples = 62\nvalue = [0, 62]\nclass = Gender'),
#  Text(0.8947368421052632, 0.5, 'Gender <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Gender'),
#  Text(0.8421052631578947, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Age'),
#  Text(0.9473684210526315, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Gender')]

# %%
# Predict Response corresponding to Predictors
y_train_pred4 = dectree4.predict(X4_train)
y_test_pred4 = dectree4.predict(X4_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree4.score(X4_train, y4_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree4.score(X4_test, y4_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y4_train, y_train_pred4),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y4_test, y_test_pred4), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

# Get confusion matrix values for train and test
cm_train4 = confusion_matrix(y4_train, y_train_pred4)
cm_test4 = confusion_matrix(y4_test, y_test_pred4)

def print_rates(cm, dataset_name=""):
    TN, FP, FN, TP = cm.ravel()

    FNR = FN / (FN + TP) if (FN + TP) != 0 else 0
    FPR = FP / (FP + TN) if (FP + TN) != 0 else 0
    TPR = TP / (TP + FN) if (TP + FN) != 0 else 0
    TNR = TN / (TN + FP) if (TN + FP) != 0 else 0

    print(f"Rates for {dataset_name} Dataset:")
    print(f"False Negative Rate (FNR): {FNR:.4f}")
    print(f"False Positive Rate (FPR): {FPR:.4f}")
    print(f"True Positive Rate (TPR / Recall): {TPR:.4f}")
    print(f"True Negative Rate (TNR / Specificity): {TNR:.4f}")
    print()

# Print rates for both train and test
print_rates(cm_train4, "Train")
print_rates(cm_test4, "Test")
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9790940766550522
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.96875
#
# Rates for Train Dataset:
# False Negative Rate (FNR): 0.0741
# False Positive Rate (FPR): 0.0000
# True Positive Rate (TPR / Recall): 0.9259
# True Negative Rate (TNR / Specificity): 1.0000
#
# Rates for Test Dataset:
# False Negative Rate (FNR): 0.1111
# False Positive Rate (FPR): 0.0000
# True Positive Rate (TPR / Recall): 0.8889
# True Negative Rate (TNR / Specificity): 1.0000

# %% [markdown]
# ### Overall:
#
# Test accuracy ranges from __71.88% to 96.88%__. Models trained on X3 (93.75%) and X4 (96.88%) clearly outperform the rest, with low FNRs (11.11%), and the lowest FPRs — especially X4 with 0.00%. Both also show high recall and perfect specificity in __X4__ (88.89%–100%). These results make X3 and X4 the most __accurate and reliable models__ in the set.
